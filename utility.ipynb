# %%
import pickle
import numpy as np

# %%
# Load data for non-defended dataset for CW setting
def LoadDataNoDefCW():

    print ("Loading non-defended dataset for closed-world scenario")
    # Point to the directory storing data
    # dataset_dir = 'ClosedWorld/'

    # X represents a sequence of traffic directions
    # y represents a sequence of corresponding label (website's label)

    # Load training data
    with open('X_train_CW_NoDef.pkl', 'rb') as handle:
        X_train = np.array(pickle.load(handle))
    with open('y_train_CW_NoDef.pkl', 'rb') as handle:
        y_train = np.array(pickle.load(handle))

    # Load validation data
    with open('X_valid_CW_NoDef.pkl', 'rb') as handle:
        X_valid = np.array(pickle.load(handle))
    with open('y_valid_CW_NoDef.pkl', 'rb') as handle:
        y_valid = np.array(pickle.load(handle))

    # Load testing data
    with open('X_test_CW_NoDef.pkl', 'rb') as handle:
        X_test = np.array(pickle.load(handle))
    with open('y_test_CW_NoDef.pkl', 'rb') as handle:
        y_test = np.array(pickle.load(handle))

    print ("Data dimensions:")
    print ("X: Training data's shape : ", X_train.shape)
    print ("y: Training data's shape : ", y_train.shape)
    print ("X: Validation data's shape : ", X_valid.shape)
    print ("y: Validation data's shape : ", y_valid.shape)
    print ("X: Testing data's shape : ", X_test.shape)
    print ("y: Testing data's shape : ", y_test.shape)

    return X_train, y_train, X_valid, y_valid, X_test, y_test

# %%
# Load data for non-defended dataset for CW setting
def LoadDataNoDefCW_EWC():

    print ("Loading non-defended dataset for closed-world scenario")
    # Point to the directory storing data
    # dataset_dir = 'ClosedWorld/'

    # X represents a sequence of traffic directions
    # y represents a sequence of corresponding label (website's label)

    # Load training data
    with open('X_A_train.pkl', 'rb') as handle:
        X_A_train = np.array(pickle.load(handle))
    with open('X_B_train.pkl', 'rb') as handle:
        X_B_train = np.array(pickle.load(handle))
    with open('y_A_train.pkl', 'rb') as handle:
        y_A_train = np.array(pickle.load(handle))
    with open('y_B_train.pkl', 'rb') as handle:
        y_B_train = np.array(pickle.load(handle))

    # Load testing data
    with open('X_A_test.pkl', 'rb') as handle:
        X_A_test = np.array(pickle.load(handle))
    with open('X_B_test.pkl', 'rb') as handle:
        X_B_test = np.array(pickle.load(handle))
    with open('y_A_test.pkl', 'rb') as handle:
        y_A_test = np.array(pickle.load(handle))
    with open('y_B_test.pkl', 'rb') as handle:
        y_B_test = np.array(pickle.load(handle))

    print ("Data dimensions:")
    print ("X_A: Training data's shape : ", X_A_train.shape)
    print ("X_B: Training data's shape : ", X_B_train.shape)
    print ("y_A: Training data's shape : ", y_A_train.shape)
    print ("y_B: Training data's shape : ", y_B_train.shape)
    print ("X_A: Testing data's shape : ", X_A_test.shape)
    print ("X_B: Testing data's shape : ", X_B_test.shape)
    print ("y_A: Testing data's shape : ", y_A_test.shape)
    print ("y_B: Testing data's shape : ", y_B_test.shape)

    return X_A_train, X_B_train, y_A_train, y_B_train, X_A_test, X_B_test, y_A_test, y_B_test

# %%
# Load data for non-defended dataset for OW training
def LoadDataNoDefOW_Training():

    print ("Loading non-defended dataset for open-world scenario for training")
    # Point to the directory storing data
    # dataset_dir = 'NAIVIS/OpenWorld/'

    # X represents a sequence of traffic directions
    # y represents a sequence of corresponding label (website's label)

    # Load training data
    with open('X_train_OW_NoDef.pkl', 'rb') as handle:
        X_train = np.array(pickle.load(handle))
    with open('y_train_OW_NoDef.pkl', 'rb') as handle:
        y_train = np.array(pickle.load(handle))

    # Load validation data
    with open('X_valid_OW_NoDef.pkl', 'rb') as handle:
        X_valid = np.array(pickle.load(handle))
    with open('y_valid_OW_NoDef.pkl', 'rb') as handle:
        y_valid = np.array(pickle.load(handle))


    print ("Data dimensions:")
    print ("X: Training data's shape : ", X_train.shape)
    print ("y: Training data's shape : ", y_train.shape)
    print ("X: Validation data's shape : ", X_valid.shape)
    print ("y: Validation data's shape : ", y_valid.shape)

    return X_train, y_train, X_valid, y_valid

# %%
# Load data for non-defended dataset for OW evaluation
def LoadDataNoDefOW_Evaluation():

    print ("Loading non-defended dataset for open-world scenario for evaluation")
    # Point to the directory storing data
    # dataset_dir = 'NAIVIS/OpenWorld/'

    # X represents a sequence of traffic directions
    # y represents a sequence of corresponding label (website's label)

    # Load training data
    with open('X_test_CW_NoDef.pkl', 'rb') as handle:
        X_test_Mon = pickle.load(handle)
    with open('y_test_CW_NoDef.pkl', 'rb') as handle:
        y_test_Mon = pickle.load(handle)
    with open('X_test_Unmon_NoDef.pkl', 'rb') as handle:
        X_test_Unmon = pickle.load(handle)
    with open('y_test_Unmon_NoDef.pkl', 'rb') as handle:
        y_test_Unmon = pickle.load(handle)

    X_test_Mon = np.array(X_test_Mon)
    y_test_Mon = np.array(y_test_Mon)
    X_test_Unmon = np.array(X_test_Unmon)
    y_test_Unmon = np.array(y_test_Unmon)

    return X_test_Mon, y_test_Mon, X_test_Unmon, y_test_Unmon
